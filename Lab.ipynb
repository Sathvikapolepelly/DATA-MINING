# %% [markdown]
# <a href="https://colab.research.google.com/github/Sathvikapolepelly/DATA-MINING/blob/main/Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
data={'categor':['a','b','c','a','b','c']}
df=pd.DataFrame(data)

# %%
df
# Out:
#   categor  Label_Encoder  categor_a  categor_b  categor_c
# 0       a              0       True      False      False
# 1       b              1      False       True      False
# 2       c              2      False      False       True
# 3       a              0       True      False      False
# 4       b              1      False       True      False
# 5       c              2      False      False       True

# %%
#label encoding
Label_Encoder=LabelEncoder()
df['Label_Encoder']=Label_Encoder.fit_transform(df['categor'])

# %%
#one_hot_encoding
one_hot_encoder=pd.get_dummies(df['categor'],prefix='categor')

# %%
df=pd.concat([df,one_hot_encoder],axis=1)

# %%
df
# Out:
#   categor  Label_Encoder  categor_a  categor_b  categor_c
# 0       a              0       True      False      False
# 1       b              1      False       True      False
# 2       c              2      False      False       True
# 3       a              0       True      False      False
# 4       b              1      False       True      False
# 5       c              2      False      False       True

# %%
from datetime import datetime

# %%
data={'Name':['Alice','Bob'],'Date_of_Birth':['1990-05-15','1995-08-20']}
df=pd.DataFrame(data)

# %%
df
# Out:
#     Name Date_of_Birth
# 0  Alice    1990-05-15
# 1    Bob    1995-08-20

# %%
df['Date_of_Birth']=pd.to_datetime(df['Date_of_Birth'])

# %%
df['Date_of_Birth']
# Out:
# 0   1990-05-15
# 1   1995-08-20
# Name: Date_of_Birth, dtype: datetime64[ns]

# %%
current_year=datetime.now().year

# %%
current_year
# Out:
# 2025

# %%
df['Age']=current_year-df['Date_of_Birth'].dt.year

# %%
df['Age']
# Out:
# 0    35
# 1    30
# Name: Age, dtype: int32

# %%
import pandas as pd

data = {'category': ['A', 'A', 'B', 'B', 'C', 'C'], 'values': [10, 20, 10, 30, 40, 50]}
df = pd.DataFrame(data)
df
# Out:
#   category  values
# 0        A      10
# 1        A      20
# 2        B      10
# 3        B      30
# 4        C      40
# 5        C      50
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['values'].plot(kind='hist', bins=20, title='values')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('category').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['values'].plot(kind='line', figsize=(8, 4), title='values')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df['category'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df, x='values', y='category', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
grouped=df.groupby('category').agg({'values':'sum'})

# %%
grouped
# Out:
#           values
# category
# A             30
# B             40
# C             90

# %%
pivot=df.pivot_table(index='category',values='values',aggfunc=['sum','mean'])

# %%
pivot
# Out:
#             sum   mean
#          values values
# category
# A            30   15.0
# B            40   20.0
# C            90   45.0
